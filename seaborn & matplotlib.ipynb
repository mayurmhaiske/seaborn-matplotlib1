# %%
# !pip install seaborn

# %%
# !pip install matplotlib

# %%
import seaborn as sns       # Import seaborn library for advanced statistical plotting
import matplotlib.pyplot as plt  # Import matplotlib for additional plot customization and display
import numpy as np          # Import numpy for numerical array operations and data generation
import pandas as pd         # Import pandas for DataFrame operations (seaborn works seamlessly with DataFrames)
import warnings
warnings.filterwarnings('ignore')

# %%
tips = sns.load_dataset("tips")         # Load restaurant tips dataset with bill amounts, tips, and customer info
iris = sns.load_dataset("iris")         # Load iris flower dataset - classic for machine learning classification
titanic = sns.load_dataset("titanic")   # Load Titanic passenger dataset with survival and demographic data
flights = sns.load_dataset("flights")   # Load airline passenger data over multiple years and months

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [raw]
# titanic.head()

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [raw]
# # ----- 3. Scatter Plot --------------------------------------------------------
# # Use a scatter plot to show relationship/correlation between two continuous variables.
# plt.figure(figsize=(8,5))
# sns.scatterplot(data=tips,              # Use the tips dataset
#                 x="total_bill",         # Set x-axis to total bill amount
#                 y="tip",               # Set y-axis to tip amount
#                 hue="sex" ,            # Color points by customer gender
#                 style="time" ,          # Use different markers for lunch vs dinner
#                 size="size"             # Make point size represent party size
#                 #sizes=(20, 200)
#                )# Set minimum and maximum point sizes
# plt.title("Scatter Plot: Total Bill vs Tip (Grouped by Sex/Time, Sized by Group)")  # Add descriptive title
# plt.xlabel("Total Bill ($)")            # Label x-axis with units for clarity
# plt.ylabel("Tip ($)")                   # Label y-axis with units for clarity
# plt.show()                              # Display the completed plot

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(7,6))
sns.scatterplot(data=tips,
                x ="total_bill",
                y ="tip",
                hue="sex",
                style="time",
                size="size")

plt.title("tejas cloud blits")
plt.xlable("Total Bill", "($)")
plt.ylable("Tip ($)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 10
#       2 sns.scatterplot(data=tips,
#       3                 x ="total_bill",
#       4                 y ="tip",
#       5                 hue="sex",
#       6                 style="time",
#       7                 size="size")
#       9 plt.title("tejas cloud blits")
# ---> 10 plt.xlable("Total Bill", "($)")
#      11 plt.ylable("Tip ($)")
#      12 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
# ----- 3. Scatter Plot --------------------------------------------------------
# Use a scatter plot to show relationship/correlation between two continuous variables.
plt.figure(figsize=(8,5))
sns.scatterplot(data=tips,              # Use the tips dataset
                x="total_bill",         # Set x-axis to total bill amount
                y="tip",               # Set y-axis to tip amount
                hue="sex" ,            # Color points by customer gender
                style="time" ,          # Use different markers for lunch vs dinner
                size="size"             # Make point size represent party size
                #sizes=(20, 200)
               )# Set minimum and maximum point sizes
plt.title("Scatter Plot: Total Bill vs Tip (Grouped by Sex/Time, Sized by Group)")  # Add descriptive title
plt.xlabel("Total Bill ($)")            # Label x-axis with units for clarity
plt.ylabel("Tip ($)")                   # Label y-axis with units for clarity
plt.show()                              # Display the completed plot

# %%
# ----- 4. Line Plot -----------------------------------------------------------
# Line plots are for trends (time series, sequences, or continuous data changes).
plt.figure(figsize=(8,5))
sns.lineplot(data=flights,              # Use the flights dataset
             x="year",                  # Set x-axis to year (time progression)
             y="passengers")            # Set y-axis to number of passengers
plt.title("Line Plot: Airline Passengers Over Years")  # Add title explaining the trend
plt.xlabel("Year")                      # Label x-axis
plt.ylabel("Number of Passengers")      # Label y-axis
plt.show()                              # Display the plot

# %%
college = sns.scatterplot("tejas")

# %%
college =
# Out:
#   Cell In[12], line 1
#     college =
#               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
df = pd.read_excel("tejas12.xlsx")
df
# Out:
#      Sr no   StudentId                        NAME DATE OF BIRTH   MOBILE NO
# 0         1    5165531             ARYA ADITYA JHA    14/01/2008  9890528397
# 1         2    5177905            ANSH MUKESH RAUT    11/05/2008  7823090653
# 2         3    5178540  SUJAL PURUSHOTTAM MOTGHARE    24/06/2008  9767761805
# 3         4    5214751      TANMAY VIVEK GHAWGHAVE    18/07/2007  9604052065
# 4         5    5240532    PRASHANSHA VIJAY JAMGADE    16/05/2008  9860170696
# ..      ...        ...                         ...           ...         ...
# 139     140    5446868         SHREYA SACHIN WANGE    13/12/2008  9970163881
# 140     141    5559723         SHRUTI RAJESH MOHOD    16/10/2006  8788713439
# 141     142    5698488        ABHIJEET KAILASH ATE    01/09/2008  7875513256
# 142     143    5759196        RITWIK BHUSHAN DUBEY    18/01/2009  7743818921
# 143     144    5827791       NAYAN PRAMOD PILLEWAR    01/09/2008  8788918776
#
# [144 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example: Scatter plot of 'height' vs 'weight'
sns.scatterplot( data = df,
                x = "StudentId",
                y= "NAME",
                hue="MOBILE NO" 
               )

plt.title('Height vs Weight')
plt.xlabel('Height "$"')
plt.ylabel('Weight $ ')
plt.show()

# %%
df
# Out:
#      Sr no   StudentId                        NAME DATE OF BIRTH   MOBILE NO
# 0         1    5165531             ARYA ADITYA JHA    14/01/2008  9890528397
# 1         2    5177905            ANSH MUKESH RAUT    11/05/2008  7823090653
# 2         3    5178540  SUJAL PURUSHOTTAM MOTGHARE    24/06/2008  9767761805
# 3         4    5214751      TANMAY VIVEK GHAWGHAVE    18/07/2007  9604052065
# 4         5    5240532    PRASHANSHA VIJAY JAMGADE    16/05/2008  9860170696
# ..      ...        ...                         ...           ...         ...
# 139     140    5446868         SHREYA SACHIN WANGE    13/12/2008  9970163881
# 140     141    5559723         SHRUTI RAJESH MOHOD    16/10/2006  8788713439
# 141     142    5698488        ABHIJEET KAILASH ATE    01/09/2008  7875513256
# 142     143    5759196        RITWIK BHUSHAN DUBEY    18/01/2009  7743818921
# 143     144    5827791       NAYAN PRAMOD PILLEWAR    01/09/2008  8788918776
#
# [144 rows x 5 columns]

# %%
df.head()
# Out:
#    Sr no   StudentId                        NAME DATE OF BIRTH   MOBILE NO
# 0       1    5165531             ARYA ADITYA JHA    14/01/2008  9890528397
# 1       2    5177905            ANSH MUKESH RAUT    11/05/2008  7823090653
# 2       3    5178540  SUJAL PURUSHOTTAM MOTGHARE    24/06/2008  9767761805
# 3       4    5214751      TANMAY VIVEK GHAWGHAVE    18/07/2007  9604052065
# 4       5    5240532    PRASHANSHA VIJAY JAMGADE    16/05/2008  9860170696

# %%
 tejas1 = df[0:6]

# %%
tejas1
# Out:
#    Sr no   StudentId                        NAME DATE OF BIRTH   MOBILE NO
# 0       1    5165531             ARYA ADITYA JHA    14/01/2008  9890528397
# 1       2    5177905            ANSH MUKESH RAUT    11/05/2008  7823090653
# 2       3    5178540  SUJAL PURUSHOTTAM MOTGHARE    24/06/2008  9767761805
# 3       4    5214751      TANMAY VIVEK GHAWGHAVE    18/07/2007  9604052065
# 4       5    5240532    PRASHANSHA VIJAY JAMGADE    16/05/2008  9860170696
# 5       6    5240584       PRIYANSHU VIKAS KAPSE    09/10/2007  9423291051

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example: Scatter plot of 'height' vs 'weight'
sns.scatterplot( data = tejas1,
                x = "StudentId",
                y= "NAME",
                hue="MOBILE NO" 
               )

plt.title('tejas excle sheet')
plt.xlabel('Height "$"')
plt.ylabel('Weight $ ')
plt.show()

# %%
# ----- 3. Scatter Plot --------------------------------------------------------
# Use a scatter plot to show relationship/correlation between two continuous variables.
plt.figure(figsize=(8,5))
sns.scatterplot(
    data=tips,              # Use the tips dataset
                x="total_bill",         # Set x-axis to total bill amount
                y="tip",               # Set y-axis to tip amount
                hue="sex" ,            # Color points by customer gender
                style="time" ,          # Use different markers for lunch vs dinner
                size="size"             # Make point size represent party size
                #sizes=(20, 200)
               )# Set minimum and maximum point sizes
plt.title("Scatter Plot: Total Bill vs Tip (Grouped by Sex/Time, Sized by Group)")  # Add descriptive title
plt.xlabel("Total Bill ($)")            # Label x-axis with units for clarity
plt.ylabel("Tip ($)")                   # Label y-axis with units for clarity
plt.show()                              # Display the completed plot

# %%
# ----- 4. Line Plot -----------------------------------------------------------
# Line plots are for trends (time series, sequences, or continuous data changes).
plt.figure(figsize=(8,5))
sns.lineplot(data=flights,              # Use the flights dataset
             x="year",                  # Set x-axis to year (time progression)
             y="passengers")            # Set y-axis to number of passengers
plt.title("Line Plot: Airline Passengers Over Years")  # Add title explaining the trend
plt.xlabel("Year")                      # Label x-axis
plt.ylabel("Number of Passengers")      # Label y-axis
plt.show()                              # Display the plot

# %%
# Example: Grouped line plot for advanced trend analysis
sns.lineplot(data=flights,              # Use the flights dataset again
             x="year",                  # Set x-axis to year
             y="passengers",            # Set y-axis to passengers
             hue="month")               # Create separate lines for each month
plt.title("Line Plot: Passengers per Month by Year")  # Title for multi-line plot
plt.xlabel("Year")                      # Label x-axis
plt.ylabel("Number of Passengers")      # Label y-axis
plt.legend(title="Month")               # Show legend with month labels
plt.show()                              # Display the multi-line plot

# %%
# ----- 5. Bar Plot ------------------------------------------------------------
# Bar plots compare numeric values across categories (mean/aggregate per category).
sns.barplot(data=titanic,               # Use the titanic dataset
            x="class",                  # Set x-axis to passenger class categories
            y="fare",                   # Set y-axis to fare amounts (will show averages)
            hue="sex",                  # Group bars by gender
            ci=None,                    # Remove confidence intervals for cleaner look
            palette="muted")            # Use muted color palette
plt.title("Bar Plot: Average Fare by Class and Gender (Titanic)")  # Descriptive title
plt.xlabel("Class")                     # Label x-axis
plt.ylabel("Average Fare")              # Label y-axis (clarifies it shows averages)
plt.show()                              # Display the bar plot

# %% [raw]
# # ----- 6. Histogram -----------------------------------------------------------
# # Histograms show distribution of a numeric variable (frequency of value bins).
# sns.histplot(data=tips,                 # Use the tips dataset
#              x="total_bill",            # Set variable to analyze
#              bins=30,                   # Divide data into 20 bins for histogram
#              kde=True,                  # Add kernel density estimate curve
#              color="teal")              # Set histogram color to teal
# plt.title("Histogram + KDE: Total Bill Distribution")  # Title explaining both histogram and KDE
# plt.xlabel("Total Bill ($)")            # Label x-axis with units
# plt.ylabel("Frequency")                 # Label y-axis to show frequency count
# plt.show()                              # Display the histogram

# %%
tejas1
# Out:
#    Sr no   StudentId                        NAME DATE OF BIRTH   MOBILE NO
# 0       1    5165531             ARYA ADITYA JHA    14/01/2008  9890528397
# 1       2    5177905            ANSH MUKESH RAUT    11/05/2008  7823090653
# 2       3    5178540  SUJAL PURUSHOTTAM MOTGHARE    24/06/2008  9767761805
# 3       4    5214751      TANMAY VIVEK GHAWGHAVE    18/07/2007  9604052065
# 4       5    5240532    PRASHANSHA VIJAY JAMGADE    16/05/2008  9860170696
# 5       6    5240584       PRIYANSHU VIKAS KAPSE    09/10/2007  9423291051

# %%
sns.histplot(data=tejas1,
             x ="Studentid",
             bins ="10",
             kde =True,
             color ="teal")
plt.title("Histogram + KDE: Total Bill Distribution")  # Title explaining both histogram and KDE
plt.xlabel("Total Bill ($)")            # Label x-axis with units
plt.ylabel("Frequency")                 # Label y-axis to show frequency count
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 sns.histplot(data=tejas1,
#       2              x ="Studentid",
#       3              bins ="10",
#       4              kde =True,
#       5              color ="teal")
#       6 plt.title("Histogram + KDE: Total Bill Distribution")  # Title explaining both histogram and KDE
#       7 plt.xlabel("Total Bill ($)")            # Label x-axis with units
#
# File ~\anaconda3\Lib\site-packages\seaborn\distributions.py:1379, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1358 def histplot(
#    1359     data=None, *,
#    1360     # Vector variables
# ...

# %%
# ----- 6. Histogram -----------------------------------------------------------
# Histograms show distribution of a numeric variable (frequency of value bins).
sns.histplot(data=tips,                 # Use the tips dataset
             x="total_bill",            # Set variable to analyze
             bins=30,                   # Divide data into 20 bins for histogram
             kde=True,                  # Add kernel density estimate curve
             color="teal")              # Set histogram color to teal
plt.title("Histogram + KDE: Total Bill Distribution")  # Title explaining both histogram and KDE
plt.xlabel("Total Bill ($)")            # Label x-axis with units
plt.ylabel("Frequency")                 # Label y-axis to show frequency count
plt.show()                              # Display the histogram

# %%
# ----- 7. Box Plot ------------------------------------------------------------
# Box plots visualize distribution, median, outliers, and compare groups/categories.
sns.boxplot(data=tips,                  # Use the tips dataset
            x="day",                    # Set x-axis to day of week categories
            y="total_bill",             # Set y-axis to total bill amounts
            hue="time",                 # Group boxes by lunch/dinner time
            palette="Set3")             # Use Set3 color palette
plt.title("Box Plot: Total Bill by Day and Time")  # Descriptive title
plt.xlabel("Day of Week")               # Label x-axis
plt.ylabel("Total Bill ($)")            # Label y-axis with units
plt.show()                              # Display the box plot

# %%
# ----- 8. Violin Plot ---------------------------------------------------------
# Violin plots show distribution, density, and median like a smoothed boxplot.
sns.violinplot(x="species",             # Set x-axis to iris species categories
               y="petal_length",        # Set y-axis to petal length measurements
               data=iris,               # Use the iris dataset
               palette="pastel")        # Use pastel color palette
plt.title("Violin Plot: Petal Length by Species (Iris)")  # Descriptive title
plt.xlabel("Species")                   # Label x-axis
plt.ylabel("Petal Length (cm)")         # Label y-axis with units
plt.show()                              # Display the violin plot

# %%
corr = tips.corr(numeric_only=True)
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# ----- 9. Heatmap -------------------------------------------------------------
# Heatmaps visualize matrix-style data (correlation/aggregation tables).
corr = tips.corr(numeric_only=True)     # Calculate correlation matrix of numeric columns only
sns.heatmap(corr,                       # Create heatmap from correlation matrix
            annot=True,               # Show correlation values in each cell
            cmap="YlGnBu" ,             # Use Yellow-Green-Blue color map
            fmt=".3f"                   # Format numbers to 2 decimal places
           )
plt.title("Heatmap: Correlation Matrix of Tips Data")  # Descriptive title
plt.show()                              # Display the heatmap

# %%
corr1 = tejas1.corr(numeric_only=True)
corr1
# Out:
#              Sr no   StudentId  MOBILE NO
# Sr no      1.000000   0.958035   0.244513
# StudentId  0.958035   1.000000   0.248038
# MOBILE NO  0.244513   0.248038   1.000000

# %%
corr = tejas1.corr(numeric_only=True)     # Calculate correlation matrix of numeric columns only
sns.heatmap(corr,                       # Create heatmap from correlation matrix
            annot=True,               # Show correlation values in each cell
            cmap="YlGnBu" ,             # Use Yellow-Green-Blue color map
            fmt=".3f"                   # Format numbers to 2 decimal places
           )
plt.title("Heatmap: Correlation Matrix of tejas1 Data")  # Descriptive title
plt.show()                              # Display the heatmap

# %%
tejas1
# Out:
#    Sr no   StudentId                        NAME DATE OF BIRTH   MOBILE NO
# 0       1    5165531             ARYA ADITYA JHA    14/01/2008  9890528397
# 1       2    5177905            ANSH MUKESH RAUT    11/05/2008  7823090653
# 2       3    5178540  SUJAL PURUSHOTTAM MOTGHARE    24/06/2008  9767761805
# 3       4    5214751      TANMAY VIVEK GHAWGHAVE    18/07/2007  9604052065
# 4       5    5240532    PRASHANSHA VIJAY JAMGADE    16/05/2008  9860170696
# 5       6    5240584       PRIYANSHU VIKAS KAPSE    09/10/2007  9423291051

# %%
tejas1_pivot = tejas1.pivot(
    index="NAME",      # Set rows to months
    columns="Sr no",     # Set columns to years
    values="MOBILE NO" # Values to fill in the table
)
print(tejas1_pivot)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sr no'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 tejas1_pivot = tejas1.pivot(
# ...

# %%
df = pd.read_excel("tej.xlsx")
df
# Out:
#      Sr no   Student                        NAME DATE OF BIRTH   MOBILE NO
# 0         1  5165531             ARYA ADITYA JHA    14/01/2008  9890528397
# 1         2  5177905            ANSH MUKESH RAUT    11/05/2008  7823090653
# 2         3  5178540  SUJAL PURUSHOTTAM MOTGHARE    24/06/2008  9767761805
# 3         4  5214751      TANMAY VIVEK GHAWGHAVE    18/07/2007  9604052065
# 4         5  5240532    PRASHANSHA VIJAY JAMGADE    16/05/2008  9860170696
# ..      ...      ...                         ...           ...         ...
# 139     140  5446868         SHREYA SACHIN WANGE    13/12/2008  9970163881
# 140     141  5559723         SHRUTI RAJESH MOHOD    16/10/2006  8788713439
# 141     142  5698488        ABHIJEET KAILASH ATE    01/09/2008  7875513256
# 142     143  5759196        RITWIK BHUSHAN DUBEY    18/01/2009  7743818921
# 143     144  5827791       NAYAN PRAMOD PILLEWAR    01/09/2008  8788918776
#
# [144 rows x 5 columns]

# %%
tej1 = df[0:10]

# %%
tej1
# Out:
#    Sr no   Student                        NAME DATE OF BIRTH   MOBILE NO
# 0       1  5165531             ARYA ADITYA JHA    14/01/2008  9890528397
# 1       2  5177905            ANSH MUKESH RAUT    11/05/2008  7823090653
# 2       3  5178540  SUJAL PURUSHOTTAM MOTGHARE    24/06/2008  9767761805
# 3       4  5214751      TANMAY VIVEK GHAWGHAVE    18/07/2007  9604052065
# 4       5  5240532    PRASHANSHA VIJAY JAMGADE    16/05/2008  9860170696
# 5       6  5240584       PRIYANSHU VIKAS KAPSE    09/10/2007  9423291051
# 6       7  5240626          PRAVIN MANOHAR UKE    23/11/2008  9699940368
# 7       8  5240723      ANJITA MILIND DHONGADE    18/06/2009  9373580104
# 8       9  5240767        SHLOK SATISH SOLANKI    14/09/2008  9309822237
# 9      10  5240809       NIDHI JAYDRATH BADOLE    28/11/2008  7083033440

# %%
# Clean column names
tej1.columns = tej1.columns.str.strip()  # Remove leading/trailing spaces
print(tej1.columns)  # Check actual column names

# Then pivot using the correct column names
tej1_pivot = tej1.pivot(
    index="NAME",
    columns="Sr no",         # Make sure this matches exactly
    values="MOBILE NO"
)

print(tej1_pivot)
# Out:
# Index(['Sr no', 'Student', 'NAME', 'DATE OF BIRTH', 'MOBILE NO'], dtype='object')
# Sr no                                 1             2             3   \
# NAME
# ANJITA MILIND DHONGADE               NaN           NaN           NaN
# ANSH MUKESH RAUT                     NaN  7.823091e+09           NaN
# ARYA ADITYA JHA             9.890528e+09           NaN           NaN
# NIDHI JAYDRATH BADOLE                NaN           NaN           NaN
# PRASHANSHA VIJAY JAMGADE             NaN           NaN           NaN
# PRAVIN MANOHAR UKE                   NaN           NaN           NaN
# PRIYANSHU VIKAS KAPSE                NaN           NaN           NaN
# SHLOK SATISH SOLANKI                 NaN           NaN           NaN
# SUJAL PURUSHOTTAM MOTGHARE           NaN           NaN  9.767762e+09
# TANMAY VIVEK GHAWGHAVE               NaN           NaN           NaN
#
# Sr no                                 4             5             6   \
# NAME
# ...

# %%
tej1_pivot = tej1.pivot(
    index="NAME",
    columns="Sr no",         # Make sure this matches exactly
    values="MOBILE NO"
)

tej1_pivot
# Out:
# Sr no                                 1             2             3   \
# NAME
# ANJITA MILIND DHONGADE               NaN           NaN           NaN
# ANSH MUKESH RAUT                     NaN  7.823091e+09           NaN
# ARYA ADITYA JHA             9.890528e+09           NaN           NaN
# NIDHI JAYDRATH BADOLE                NaN           NaN           NaN
# PRASHANSHA VIJAY JAMGADE             NaN           NaN           NaN
# PRAVIN MANOHAR UKE                   NaN           NaN           NaN
# PRIYANSHU VIKAS KAPSE                NaN           NaN           NaN
# SHLOK SATISH SOLANKI                 NaN           NaN           NaN
# SUJAL PURUSHOTTAM MOTGHARE           NaN           NaN  9.767762e+09
# TANMAY VIVEK GHAWGHAVE               NaN           NaN           NaN
#
# Sr no                                 4             5             6   \
# NAME
# ANJITA MILIND DHONGADE               NaN           NaN           NaN
# ...

# %%
tejas1_pivot = tejas1.pivot(
    index="NAME",      # Set rows to months
    columns="Sr no",     # Set columns to years
    values="MOBILE NO" # Values to fill in the table
)
tejas1_pivot
# Out:
# Sr no                                  1             2             3  \
# NAME
# ANSH MUKESH RAUT                     NaN  7.823091e+09           NaN
# ARYA ADITYA JHA             9.890528e+09           NaN           NaN
# PRASHANSHA VIJAY JAMGADE             NaN           NaN           NaN
# PRIYANSHU VIKAS KAPSE                NaN           NaN           NaN
# SUJAL PURUSHOTTAM MOTGHARE           NaN           NaN  9.767762e+09
# TANMAY VIVEK GHAWGHAVE               NaN           NaN           NaN
#
# Sr no                                  4             5             6
# NAME
# ANSH MUKESH RAUT                     NaN           NaN           NaN
# ARYA ADITYA JHA                      NaN           NaN           NaN
# PRASHANSHA VIJAY JAMGADE             NaN  9.860171e+09           NaN
# PRIYANSHU VIKAS KAPSE                NaN           NaN  9.423291e+09
# SUJAL PURUSHOTTAM MOTGHARE           NaN           NaN           NaN
# ...

# %%
# Example: Pivot table for heatmap
tejas1_pivot = tejas1.pivot(
    index="NAME",      # Set rows to months
    columns="Sr no",     # Set columns to years
    values="MOBILE NO" # Values to fill in the table
)

sns.heatmap(tejas1_pivot,              # Create heatmap from pivot table
            cmap='Blues',               # Use blues color map
            annot=True,                 # Show passenger numbers in cells
            fmt='d')                    # Format numbers as integers (no decimals)
plt.title("TEJAS EXCLE DATA ")  # Descriptive title
plt.xlabel("NAMES")                      # Label x-axis
plt.ylabel("Sr no")                     # Label y-axis
plt.show()                              # Display the pivot heatmap
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 8
#       1 # Example: Pivot table for heatmap
#       2 tejas1_pivot = tejas1.pivot(
#       3     index="NAME",      # Set rows to months
#       4     columns="Sr no",     # Set columns to years
#       5     values="MOBILE NO" # Values to fill in the table
#       6 )
# ----> 8 sns.heatmap(tejas1_pivot,              # Create heatmap from pivot table
#       9             cmap='Blues',               # Use blues color map
#      10             annot=True,                 # Show passenger numbers in cells
#      11             fmt='d')                    # Format numbers as integers (no decimals)
#      12 plt.title("TEJAS EXCLE DATA ")  # Descriptive title
#      13 plt.xlabel("NAMES")                      # Label x-axis
#
# ...

# %%
# ----- 10. Pair Plot ----------------------------------------------------------
# Pair plots explore pairwise relationships among numeric variables.
sns.pairplot(iris,                      # Use the iris dataset
             hue="species",             # Color points by species
             diag_kind="kde",           # Use KDE plots on diagonal (instead of histograms)
             palette="husl")            # Use HUSL color palette
plt.suptitle("Pair Plot: Iris Dataset", y=1.02)  # Add main title slightly above the grid
plt.show()                              # Display the pair plot grid

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
tej1
# Out:
#    Sr no  Student                        NAME DATE OF BIRTH   MOBILE NO
# 0      1  5165531             ARYA ADITYA JHA    14/01/2008  9890528397
# 1      2  5177905            ANSH MUKESH RAUT    11/05/2008  7823090653
# 2      3  5178540  SUJAL PURUSHOTTAM MOTGHARE    24/06/2008  9767761805
# 3      4  5214751      TANMAY VIVEK GHAWGHAVE    18/07/2007  9604052065
# 4      5  5240532    PRASHANSHA VIJAY JAMGADE    16/05/2008  9860170696
# 5      6  5240584       PRIYANSHU VIKAS KAPSE    09/10/2007  9423291051
# 6      7  5240626          PRAVIN MANOHAR UKE    23/11/2008  9699940368
# 7      8  5240723      ANJITA MILIND DHONGADE    18/06/2009  9373580104
# 8      9  5240767        SHLOK SATISH SOLANKI    14/09/2008  9309822237
# 9     10  5240809       NIDHI JAYDRATH BADOLE    28/11/2008  7083033440

# %%
sns.pairplot(tej1,                      # Use the iris dataset
             hue="DATE_OF_BIRTH",             # Color points by species
             diag_kind="kde",           # Use KDE plots on diagonal (instead of histograms)
             palette="husl")            # Use HUSL color palette
plt.suptitle("Pair Plot: Iris Dataset", y=1.02)  # Add main title slightly above the grid
plt.show()                              # Display the pair plot grid
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DATE_OF_BIRTH'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 sns.pairplot(tej1,                      # Use the iris dataset
# ...
